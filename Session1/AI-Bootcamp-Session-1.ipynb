# %% [markdown]
# # Time Series Dataset

# %% [markdown]
# #stock price data is a time series data. Let's take a look at Apple stock price data; this data can be downloaded from the NASDAQ site (https://www.nasdaq.com/symbol/aapl/historical).

# %%
import datetime
from pandas_datareader import DataReader
from matplotlib import pyplot as plt
# %matplotlib inline


Apple = DataReader("AAPL", "yahoo", 
        start=datetime.datetime(2010, 1, 1), 
        end=datetime.datetime(2015,12,31)) 
Apple.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2009-12-31  30.478571  30.080000  30.447144  30.104286   88102700.0  20.073631
# 2010-01-04  30.642857  30.340000  30.490000  30.572857  123432400.0  20.386072
# 2010-01-05  30.798571  30.464285  30.657143  30.625713  150476200.0  20.421322
# 2010-01-06  30.747143  30.107143  30.625713  30.138571  138040000.0  20.096491
# 2010-01-07  30.285715  29.864286  30.250000  30.082857  119282800.0  20.059338

# %%
close = Apple['Adj Close']
plt.figure(figsize= (10,10))
close.plot()
plt.ylabel("Apple stock close price")
plt.show()

# %% [markdown]
# # Relational Dataset
# https://data.crunchbase.com/docs/daily-csv-export

# %% [markdown]
# # Natural Language - Text

# %%
f = open('text_data.txt')
text = f.read()
print(text)
# Out:
# When computers were introduced in Industry 3.0, it was disruptive thanks to the addition of an entirely new technology. Now, and into the future as Industry 4.0 unfolds, computers are connected and communicate with one another to ultimately make decisions without human involvement. A combination of cyber-physical systems, the Internet of Things and the Internet of Systems make Industry 4.0 possible and the smart factory a reality. As a result of the support of smart machines that keep getting smarter as they get access to more data, our factories will become more efficient and productive and less wasteful. Ultimately, it's the network of these machines that are digitally connected with one another and create and share information that results in the true power of Industry 4.0.

# %%
# clean data
import re
# remove Punctuation
text = re.sub(r"[^a-zA-Z0-9]", " ", text) 
print(text)
# Out:
# When computers were introduced in Industry 3 0  it was disruptive thanks to the addition of an entirely new technology  Now  and into the future as Industry 4 0 unfolds  computers are connected and communicate with one another to ultimately make decisions without human involvement  A combination of cyber physical systems  the Internet of Things and the Internet of Systems make Industry 4 0 possible and the smart factory a reality  As a result of the support of smart machines that keep getting smarter as they get access to more data  our factories will become more efficient and productive and less wasteful  Ultimately  it s the network of these machines that are digitally connected with one another and create and share information that results in the true power of Industry 4 0

# %%
# Normalize text
# Convert to lowercase
text = text.lower() 
print(text)
# Out:
# when computers were introduced in industry 3 0  it was disruptive thanks to the addition of an entirely new technology  now  and into the future as industry 4 0 unfolds  computers are connected and communicate with one another to ultimately make decisions without human involvement  a combination of cyber physical systems  the internet of things and the internet of systems make industry 4 0 possible and the smart factory a reality  as a result of the support of smart machines that keep getting smarter as they get access to more data  our factories will become more efficient and productive and less wasteful  ultimately  it s the network of these machines that are digitally connected with one another and create and share information that results in the true power of industry 4 0

# %%
import os
import nltk
nltk.download('punkt') 
from nltk.tokenize import word_tokenize

# Split text into words using NLTK
words_nltk = word_tokenize(text)
print(words_nltk)
# Out:
# ['when', 'computers', 'were', 'introduced', 'in', 'industry', '3', '0', 'it', 'was', 'disruptive', 'thanks', 'to', 'the', 'addition', 'of', 'an', 'entirely', 'new', 'technology', 'now', 'and', 'into', 'the', 'future', 'as', 'industry', '4', '0', 'unfolds', 'computers', 'are', 'connected', 'and', 'communicate', 'with', 'one', 'another', 'to', 'ultimately', 'make', 'decisions', 'without', 'human', 'involvement', 'a', 'combination', 'of', 'cyber', 'physical', 'systems', 'the', 'internet', 'of', 'things', 'and', 'the', 'internet', 'of', 'systems', 'make', 'industry', '4', '0', 'possible', 'and', 'the', 'smart', 'factory', 'a', 'reality', 'as', 'a', 'result', 'of', 'the', 'support', 'of', 'smart', 'machines', 'that', 'keep', 'getting', 'smarter', 'as', 'they', 'get', 'access', 'to', 'more', 'data', 'our', 'factories', 'will', 'become', 'more', 'efficient', 'and', 'productive', 'and', 'less', 'wasteful', 'ultimately', 'it', 's', 'the', 'network', 'of', 'these', 'machines', 'that', 'are', 'digitally', 'connected', 'with', 'one', 'another', 'and', 'create', 'and', 'share', 'information', 'that', 'results', 'in', 'the', 'true', 'power', 'of', 'industry', '4', '0']
# [nltk_data] Downloading package punkt to /home/msaleem/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
#Remove stop words
words = [w for w in words_nltk \
        if w not in stopwords.words("english")]

print (words)
# Out:
# ['computers', 'introduced', 'industry', '3', '0', 'disruptive', 'thanks', 'addition', 'entirely', 'new', 'technology', 'future', 'industry', '4', '0', 'unfolds', 'computers', 'connected', 'communicate', 'one', 'another', 'ultimately', 'make', 'decisions', 'without', 'human', 'involvement', 'combination', 'cyber', 'physical', 'systems', 'internet', 'things', 'internet', 'systems', 'make', 'industry', '4', '0', 'possible', 'smart', 'factory', 'reality', 'result', 'support', 'smart', 'machines', 'keep', 'getting', 'smarter', 'get', 'access', 'data', 'factories', 'become', 'efficient', 'productive', 'less', 'wasteful', 'ultimately', 'network', 'machines', 'digitally', 'connected', 'one', 'another', 'create', 'share', 'information', 'results', 'true', 'power', 'industry', '4', '0']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/msaleem/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)
# Out:
# ['comput', 'introduc', 'industri', '3', '0', 'disrupt', 'thank', 'addit', 'entir', 'new', 'technolog', 'futur', 'industri', '4', '0', 'unfold', 'comput', 'connect', 'commun', 'one', 'anoth', 'ultim', 'make', 'decis', 'without', 'human', 'involv', 'combin', 'cyber', 'physic', 'system', 'internet', 'thing', 'internet', 'system', 'make', 'industri', '4', '0', 'possibl', 'smart', 'factori', 'realiti', 'result', 'support', 'smart', 'machin', 'keep', 'get', 'smarter', 'get', 'access', 'data', 'factori', 'becom', 'effici', 'product', 'less', 'wast', 'ultim', 'network', 'machin', 'digit', 'connect', 'one', 'anoth', 'creat', 'share', 'inform', 'result', 'true', 'power', 'industri', '4', '0']

# %%
nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer
# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)
# Out:
# [nltk_data] Downloading package wordnet to /home/msaleem/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['computer', 'introduced', 'industry', '3', '0', 'disruptive', 'thanks', 'addition', 'entirely', 'new', 'technology', 'future', 'industry', '4', '0', 'unfolds', 'computer', 'connected', 'communicate', 'one', 'another', 'ultimately', 'make', 'decision', 'without', 'human', 'involvement', 'combination', 'cyber', 'physical', 'system', 'internet', 'thing', 'internet', 'system', 'make', 'industry', '4', '0', 'possible', 'smart', 'factory', 'reality', 'result', 'support', 'smart', 'machine', 'keep', 'getting', 'smarter', 'get', 'access', 'data', 'factory', 'become', 'efficient', 'productive', 'le', 'wasteful', 'ultimately', 'network', 'machine', 'digitally', 'connected', 'one', 'another', 'create', 'share', 'information', 'result', 'true', 'power', 'industry', '4', '0']

# %% [markdown]
# # Natural Language - Audio

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Get the file path to the included audio example
filename = 'cartoon-birds-2_daniel-simion.wav'
filename2 = 'airplane-landing_daniel_simion.wav'
# filename = librosa.util.example_audio_file()

# %%
input_length=16000*4

def audio_norm(data):
    # Function to Normalize
    max_data = np.max(data)
    min_data = np.min(data)
    data = (data-min_data)/(max_data-min_data) 
    return data

def load_audio_file(file_path, 
            input_length=input_length):
    # Function to load an audio file and 
    # return a 1D numpy array 
    data, sr = librosa.load(file_path, sr=None)
    print ('Sampling Rate: ', sr)
    
 
    max_offset = abs(len(data)-input_length)
    print ('Max Offset: ', max_offset)
    
    offset = 0
    #offset = np.random.randint(max_offset)
    #print ('Offset: ', offset)
    
    if len(data)>input_length:
        data = data[offset:(input_length+offset)]
    else:
        data = np.pad(data, (offset, 
            input_length - len(data) - offset), 
            "constant")
 
    data = audio_norm(data)
    return data

# %%
data_base = load_audio_file(filename)
data_base2 = load_audio_file(filename2)

fig = plt.figure(figsize=(14, 8))
plt.title('Raw wave ')
plt.ylabel('Amplitude')
plt.plot(np.linspace(0, 1, input_length), data_base)
plt.show()

fig = plt.figure(figsize=(14, 8))
plt.title('Raw wave ')
plt.ylabel('Amplitude')
plt.plot(np.linspace(0, 1, input_length), data_base2)
plt.show()
# Out:
# Sampling Rate:  44100
# Max Offset:  208763
# Sampling Rate:  44100
# Max Offset:  559681

# %% [markdown]
# # Computer Vision - Images

# %%
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

image_path = 'lena.jpg'
image = cv2.imread(image_path) # BGR image
print (image.shape) # rows, columns and channels
# Out:
# (1960, 1960, 3)

# %%
#image1 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)
#cv2.imshow('Image',gray)
#cv2.waitKey(2)

# %%
ROI = image[280:1000, 330:1000]
plt.imshow(ROI)
# cv2.imshow('Image',ROI)
# cv2.waitKey(0)

# %%
print(image)
# Out:
# [[[ 57 104 156]
#   [ 58 104 158]
#   [ 58 104 158]
#   ...
#   [  9  30  57]
#   [  5  28  54]
#   [  8  30  58]]
#
#  [[ 57 104 156]
#   [ 58 104 158]
#   [ 59 105 159]
#   ...
#   [  8  31  57]
#   [  4  27  53]
#   [  7  29  57]]
#
#  [[ 57 104 156]
#   [ 59 105 159]
#   [ 59 105 159]
#   ...
#   [  9  32  58]
#   [  7  30  56]
#   [ 10  33  59]]
#
#  ...
#
#  [[  9  31  56]
#   [  8  30  55]
#   [  8  30  55]
#   ...
#   [ 47  74 118]
#   [ 45  72 116]
#   [ 44  71 115]]
#
#  [[  9  32  58]
#   [  7  30  56]
#   [  8  29  56]
#   ...
#   [ 47  74 118]
#   [ 46  73 117]
#   [ 46  73 117]]
#
#  [[ 13  36  62]
#   [  9  32  58]
#   [  7  30  56]
#   ...
#   [ 45  72 116]
#   [ 47  74 118]
#   [ 49  76 120]]]

# %%
resize1 = cv2.resize(image, (0,0), fx=0.5, fy=0.5)
print (resize1.shape)
resize2 = cv2.resize(image, (100, 50)) 
print (resize2.shape)
# Out:
# (980, 980, 3)
# (50, 100, 3)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blur1 = cv2.blur(image,(5,5))
blur2 = cv2.GaussianBlur(image,(13,13),0)
#print (gray.dtype)
# cv2.imshow('sss',blur1)
# cv2.waitKey(0)
plt.imshow(blur1)
#cv2.imshow('sss',blur1)
#cv2.waitKey(0)

# %%
plt.imshow(blur2)

# %%
cv2.imwrite('results.jpg',blur2)
# Out:
# True

# %% [markdown]
# # Computer Vision - Videos

# %%
import cv2

source = 0
cap = cv2.VideoCapture(source)

while(1):
    hasFrame, frame = cap.read()
    
    if not hasFrame:
        print ("Unable to fetch frames")
    
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow("Face Detection Comparison", frame)
    k = cv2.waitKey(10)
    if k == ord('q'):
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-85ee362bbfe7> in <module>
#       6
#       7 while(1):
# ----> 8     hasFrame, frame = cap.read()
#       9
#      10     if not hasFrame:
#
# KeyboardInterrupt:
