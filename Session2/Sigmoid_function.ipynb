# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
# Plotting Sigmoidal Activation function
x = np.linspace(-10,10,50)
X = tf.placeholder(tf.float32, shape = None)
W = tf.constant(np.random.random())
bias = tf.constant(np.random.random()) #tf.constant(0.0)
h = W*X + bias
out = tf.sigmoid(h)
out_d = out*(1-out)
init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    y, y_d, w, b = sess.run([out,out_d, W, bias], feed_dict={X:x})
#print("W= {} b= {}".format(w,b))
plt.plot(x, y)
plt.plot(x, y_d)
plt.grid(b=True)
plt.xlabel('Activity of Neuron')
plt.ylabel('Output of Neuron')
plt.title('Sigmoidal Activation Function for weight %f and bias 0.0' %w)
# Out:
# Text(0.5, 1.0, 'Sigmoidal Activation Function for weight 0.652942 and bias 0.0')
